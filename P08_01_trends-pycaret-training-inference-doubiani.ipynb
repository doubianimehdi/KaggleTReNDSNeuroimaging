# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#1.-Introduction-to-PyCaret" data-toc-modified-id="1.-Introduction-to-PyCaret-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>1. Introduction to PyCaret</a></span><ul class="toc-item"><li><span><a href="#1.1-Installation-(Let's-install-PyCaret)" data-toc-modified-id="1.1-Installation-(Let's-install-PyCaret)-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>1.1 Installation (Let's install PyCaret)</a></span></li><li><span><a href="#2-Importing-Libraries" data-toc-modified-id="2-Importing-Libraries-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>2 Importing Libraries</a></span></li><li><span><a href="#2.1-Load-Data" data-toc-modified-id="2.1-Load-Data-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>2.1 Load Data</a></span></li><li><span><a href="#2.2-Utils" data-toc-modified-id="2.2-Utils-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>2.2 Utils</a></span></li><li><span><a href="#3.-Let's-proceed-with-PyCaret-for-regression" data-toc-modified-id="3.-Let's-proceed-with-PyCaret-for-regression-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>3. Let's proceed with PyCaret for regression</a></span><ul class="toc-item"><li><span><a href="#3.1-Setup-our-dataset-(For-demo-just-using-age-target)" data-toc-modified-id="3.1-Setup-our-dataset-(For-demo-just-using-age-target)-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>3.1 Setup our dataset (For demo just using <code>age</code> target)</a></span></li><li><span><a href="#3.2-Compare-Models" data-toc-modified-id="3.2-Compare-Models-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>3.2 Compare Models</a></span></li><li><span><a href="#3.3-Create-Model" data-toc-modified-id="3.3-Create-Model-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>3.3 Create Model</a></span></li><li><span><a href="#3.4-Tune-Model-Hyperparameters" data-toc-modified-id="3.4-Tune-Model-Hyperparameters-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>3.4 Tune Model Hyperparameters</a></span></li><li><span><a href="#3.5-Plot-Model" data-toc-modified-id="3.5-Plot-Model-1.5.5"><span class="toc-item-num">1.5.5&nbsp;&nbsp;</span>3.5 Plot Model</a></span></li><li><span><a href="#3.5.1-Plotting-learning-curve" data-toc-modified-id="3.5.1-Plotting-learning-curve-1.5.6"><span class="toc-item-num">1.5.6&nbsp;&nbsp;</span>3.5.1 Plotting learning curve</a></span></li><li><span><a href="#3.5.2-plotting-residuals" data-toc-modified-id="3.5.2-plotting-residuals-1.5.7"><span class="toc-item-num">1.5.7&nbsp;&nbsp;</span>3.5.2 plotting residuals</a></span></li><li><span><a href="#3.5.3-plotting-feature-importance" data-toc-modified-id="3.5.3-plotting-feature-importance-1.5.8"><span class="toc-item-num">1.5.8&nbsp;&nbsp;</span>3.5.3 plotting feature importance</a></span></li><li><span><a href="#3.6-Evaluate-Model" data-toc-modified-id="3.6-Evaluate-Model-1.5.9"><span class="toc-item-num">1.5.9&nbsp;&nbsp;</span>3.6 Evaluate Model</a></span></li><li><span><a href="#3.7-Interpret-Model" data-toc-modified-id="3.7-Interpret-Model-1.5.10"><span class="toc-item-num">1.5.10&nbsp;&nbsp;</span>3.7 Interpret Model</a></span></li><li><span><a href="#3.8-Predict-Model" data-toc-modified-id="3.8-Predict-Model-1.5.11"><span class="toc-item-num">1.5.11&nbsp;&nbsp;</span>3.8 Predict Model</a></span></li></ul></li><li><span><a href="#4.-Let's-Proceed-With-Other-Targets" data-toc-modified-id="4.-Let's-Proceed-With-Other-Targets-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>4. Let's Proceed With Other Targets</a></span><ul class="toc-item"><li><span><a href="#4.1.-comparing-models-for-age" data-toc-modified-id="4.1.-comparing-models-for-age-1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>4.1. comparing models for <code>age</code></a></span></li><li><span><a href="#4.2.-comparing-models-for-domain1_var1" data-toc-modified-id="4.2.-comparing-models-for-domain1_var1-1.6.2"><span class="toc-item-num">1.6.2&nbsp;&nbsp;</span>4.2. comparing models for <code>domain1_var1</code></a></span></li><li><span><a href="#4.3.-comparing-models-for-domain1_var2" data-toc-modified-id="4.3.-comparing-models-for-domain1_var2-1.6.3"><span class="toc-item-num">1.6.3&nbsp;&nbsp;</span>4.3. comparing models for <code>domain1_var2</code></a></span></li><li><span><a href="#4.4.-comparing-models-for-domain2_var1" data-toc-modified-id="4.4.-comparing-models-for-domain2_var1-1.6.4"><span class="toc-item-num">1.6.4&nbsp;&nbsp;</span>4.4. comparing models for <code>domain2_var1</code></a></span></li><li><span><a href="#4.5.-comparing-models-for-domain2_var2" data-toc-modified-id="4.5.-comparing-models-for-domain2_var2-1.6.5"><span class="toc-item-num">1.6.5&nbsp;&nbsp;</span>4.5. comparing models for <code>domain2_var2</code></a></span></li><li><span><a href="#Observations:" data-toc-modified-id="Observations:-1.6.6"><span class="toc-item-num">1.6.6&nbsp;&nbsp;</span>Observations:</a></span></li></ul></li><li><span><a href="#5.-Tuning-Selected-Models" data-toc-modified-id="5.-Tuning-Selected-Models-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>5. Tuning Selected Models</a></span><ul class="toc-item"><li><span><a href="#5.1-Tuning-Bayesian-Ridge-Model-for-age" data-toc-modified-id="5.1-Tuning-Bayesian-Ridge-Model-for-age-1.7.1"><span class="toc-item-num">1.7.1&nbsp;&nbsp;</span>5.1 Tuning Bayesian Ridge Model for <code>age</code></a></span></li><li><span><a href="#5.2-Tuning-CatBoost-Regressor-Model-for-domain1_var1" data-toc-modified-id="5.2-Tuning-CatBoost-Regressor-Model-for-domain1_var1-1.7.2"><span class="toc-item-num">1.7.2&nbsp;&nbsp;</span>5.2 Tuning CatBoost Regressor Model for <code>domain1_var1</code></a></span></li><li><span><a href="#5.3-Tuning-Support-Vector-Machines-Model-for-domain1_var2" data-toc-modified-id="5.3-Tuning-Support-Vector-Machines-Model-for-domain1_var2-1.7.3"><span class="toc-item-num">1.7.3&nbsp;&nbsp;</span>5.3 Tuning Support Vector Machines Model for <code>domain1_var2</code></a></span></li><li><span><a href="#5.4-Tuning-CatBoost-Regressor-Model-for-domain2_var1" data-toc-modified-id="5.4-Tuning-CatBoost-Regressor-Model-for-domain2_var1-1.7.4"><span class="toc-item-num">1.7.4&nbsp;&nbsp;</span>5.4 Tuning CatBoost Regressor Model for <code>domain2_var1</code></a></span></li><li><span><a href="#5.5-Tuning-CatBoost-Regressor-Model-for-domain2_var2" data-toc-modified-id="5.5-Tuning-CatBoost-Regressor-Model-for-domain2_var2-1.7.5"><span class="toc-item-num">1.7.5&nbsp;&nbsp;</span>5.5 Tuning CatBoost Regressor Model for <code>domain2_var2</code></a></span></li></ul></li><li><span><a href="#6.-Finalize,-save-model-and-Inference" data-toc-modified-id="6.-Finalize,-save-model-and-Inference-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>6. Finalize, save model and Inference</a></span></li><li><span><a href="#Create-Submission" data-toc-modified-id="Create-Submission-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Create Submission</a></span></li></ul></li><li><span><a href="#References" data-toc-modified-id="References-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>References</a></span></li><li><span><a href="#END-NOTES" data-toc-modified-id="END-NOTES-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>END NOTES</a></span></li></ul></div>

# %% [markdown]
# # 1. Introduction to PyCaret
#
# PyCaret is an open source, **low-code** machine learning library in Python that aims to reduce the cycle time from hypothesis to insights. It is well suited for **seasoned data scientists** who want to increase the productivity of their ML experiments by using PyCaret in their workflows or for **citizen data scientists** and those **new to data science** with little or no background in coding. PyCaret allows you to go from preparing your data to deploying your model within seconds using your choice of notebook environment. Please click [this](https://pycaret.org/guide/) link to continue learning more about PyCaret.
#
#
# **<span style="color:Red">Please upvote this kernel if you like it . It motivates me to produce more quality content :)**
#
# NOTE : This notebook is derived from this excellent one : https://www.kaggle.com/rohitsingh9990/trends-pycaret-training-inference I have just done the training with my results.

# %% [markdown]
# ![pycaret](https://miro.medium.com/max/1400/1*Q34J2tT_yGrVV0NU38iMig.jpeg)

# %% [markdown]
# ## 1.1 Installation (Let's install PyCaret)

# %%
#!pip install pycaret --quiet

# %% [markdown]
# ## 2 Importing Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold

#import regression module
from pycaret.regression import *

# %% [markdown]
# ## 2.1 Load Data

# %%
BASE_PATH = 'C:/OpenClassRooms/projet 8/trends-assessment-prediction'

fnc_df = pd.read_csv(f"{BASE_PATH}/fnc.csv")
loading_df = pd.read_csv(f"{BASE_PATH}/loading.csv")
labels_df = pd.read_csv(f"{BASE_PATH}/train_scores.csv")

# %%
fnc_features, loading_features = list(fnc_df.columns[1:]), list(loading_df.columns[1:])
df = fnc_df.merge(loading_df, on="Id")
labels_df["is_train"] = True
df = df.merge(labels_df, on="Id", how="left")

test_df = df[df["is_train"] != True].copy()
df = df[df["is_train"] == True].copy()
print(f'Shape of train data: {df.shape}, Shape of test data: {test_df.shape}')
# Out:
# Shape of train data: (5877, 1411), Shape of test data: (5877, 1411)

# %%
target_cols = ['age', 'domain1_var1', 'domain1_var2', 'domain2_var1', 'domain2_var2']
df.drop(['is_train'], axis=1, inplace=True)
test_df = test_df.drop(target_cols + ['is_train'], axis=1)


# Giving less importance to FNC features since they are easier to overfit due to high dimensionality.
FNC_SCALE = 1/500
df[fnc_features] *= FNC_SCALE
test_df[fnc_features] *= FNC_SCALE

# %% [markdown]
# ## 2.2 Utils

# %%
def get_train_data(target):
    other_targets = [tar for tar in target_cols if tar != target]
    train_df = df.drop( other_targets, axis=1)
    return train_df

# %% [markdown]
# ## 3. Let's proceed with PyCaret for regression

# %% [markdown]
# Before proceeding let me clear few things:
# * Currently `PyCaret` do not have support for multitarget regression. So, instead of 1 model for our 5 targets, we need to create individual model for each target.

# %% [markdown]
# ### 3.1 Setup our dataset (For demo just using `age` target)
#
# * `setup` function initializes the environment in pycaret and creates the transformation pipeline to prepare the data for modeling and deployment. setup() must called before executing any other function in pycaret. It takes two mandatory parameters: dataframe {array-like, sparse matrix} and name of the target column. All other parameters are optional.
#
#
#
# For more info please visit https://pycaret.org/regression/#setup

# %%
target = 'age'

train_df = get_train_data(target)

setup_reg = setup(
    data = train_df,
    target = target,
    train_size=0.8,
    numeric_imputation = 'mean',
    silent = True
)
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow0_col1" class="data row0 col1" >5310</td>
#             </tr>
#             <tr>
#                         <th id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow1_col0" class="data row1 col0" >Transform Target </td>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow1_col1" class="data row1 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow2_col0" class="data row2 col0" >Transform Target Method</td>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow3_col1" class="data row3 col1" >(5877, 1406)</td>
#             </tr>
#             <tr>
#                         <th id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710alevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710alevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow5_col1" class="data row5 col1" >1405</td>
#             </tr>
#             <tr>
#                         <th id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710alevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow6_col1" class="data row6 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710alevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710alevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710alevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710alevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow10_col1" class="data row10 col1" >(5877, 1406)</td>
#             </tr>
#             <tr>
#                         <th id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710alevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow11_col1" class="data row11 col1" >(4701, 1405)</td>
#             </tr>
#             <tr>
#                         <th id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710alevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow12_col1" class="data row12 col1" >(1176, 1405)</td>
#             </tr>
#             <tr>
#                         <th id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710alevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710alevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710alevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710alevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710alevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710alevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow18_col0" class="data row18 col0" >Transformation Method </td>
#                         <td id="T_4ced4f1e_91bd_11ea_8f09_001a7dda710arow18_col1" class="data row18 col1" >None</td>

# %% [markdown]
# ### 3.2 Compare Models
#
# * `compare_models` function uses all models in the model library and scores them using K-fold Cross Validation. The output prints a score grid that shows MAE, MSE, RMSE, R2, RMSLE and MAPE by fold (default CV = 10 Folds) of all the available models in model library.
#
#
#
# For more info please visit https://pycaret.org/regression/#compare-models

# %%
# There are few models which take a lot of time, ignoring those models to make demo faster.
blacklist_models = ['tr']

# %%
compare_models(
    blacklist = blacklist_models,
    fold = 10,
    sort = 'MAE', ## competition metric
    turbo = True
)
# Out:
# <style  type="text/css" >
#     #T_7dc941ca_9178_11ea_a132_001a7dda710a th {
#           text-align: left;
#     }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow0_col0 {
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow0_col4 {
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow0_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow1_col0 {
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow1_col2 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow1_col4 {
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow2_col0 {
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow2_col4 {
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow3_col0 {
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow3_col4 {
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow4_col0 {
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow4_col4 {
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow5_col0 {
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow5_col4 {
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow6_col0 {
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow6_col4 {
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow7_col0 {
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow7_col4 {
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow8_col0 {
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow8_col2 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow8_col3 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow8_col4 {
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow8_col5 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow8_col6 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow9_col0 {
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow9_col1 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow9_col2 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow9_col3 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow9_col4 {
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow9_col5 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow9_col6 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow10_col0 {
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow10_col1 {
#             : ;
#             text-align:  left;
#         }    #T_7dc941ca_9178_11ea_a132_001a7dda710arow10_col2 {
#             : ;
#             text-align:  left;
#         }    #T_

# %% [markdown]
# ### 3.3 Create Model
# For demo purpose let's create a Bayesian Ridge
#
# * `create_model` function creates a model and scores it using K-fold Cross Validation. (default = 10 Fold). The output prints a score grid that shows MAE, MSE, RMSE, RMSLE, R2 and MAPE. This function returns a trained model object. setup() function must be called before using create_model()
#
#
#
# For more info please visit https://pycaret.org/regression/#create-model

# %%
br_age = create_model(
    estimator='br',
    fold=10
)
# Out:
#          MAE      MSE    RMSE      R2   RMSLE    MAPE
# 0     7.0647  80.0074  8.9447  0.5572  0.1945  0.1594
# 1     7.1649  79.9125  8.9394  0.5509  0.2030  0.1666
# 2     7.2793  85.8612  9.2661  0.5326  0.2202  0.1786
# 3     7.1389  81.7431  9.0412  0.5386  0.1947  0.1617
# 4     6.7749  74.4708  8.6296  0.5895  0.1938  0.1556
# 5     7.4633  89.2604  9.4478  0.5051  0.2127  0.1721
# 6     7.4320  87.8510  9.3729  0.5378  0.2201  0.1809
# 7     7.1628  82.4321  9.0792  0.5375  0.2040  0.1647
# 8     7.0269  82.9781  9.1092  0.5291  0.2134  0.1710
# 9     7.3239  85.0439  9.2219  0.5281  0.2145  0.1775
# Mean  7.1832  82.9561  9.1052  0.5407  0.2071  0.1688
# SD    0.1942   4.1013  0.2264  0.0210  0.0099  0.0082

# %% [markdown]
# ### 3.4 Tune Model Hyperparameters
#
# * `tune_model` function tunes the hyperparameters of a model and scores it using K-fold Cross Validation. The output prints the score grid that shows MAE, MSE, RMSE, R2, RMSLE and MAPE by fold (by default = 10 Folds). This function returns a trained model object.
#
#
#
# For more info please visit https://pycaret.org/regression/#tune-model

# %%
# here we are tuning the above created model
tuned_br_age = tune_model(
    estimator='br',
    fold=10,
    optimize = 'mae',
    n_iter=50
)
# Out:
#          MAE      MSE    RMSE      R2   RMSLE    MAPE
# 0     7.0647  80.0071  8.9447  0.5572  0.1945  0.1594
# 1     7.1649  79.9121  8.9394  0.5509  0.2030  0.1666
# 2     7.2793  85.8608  9.2661  0.5326  0.2202  0.1786
# 3     7.1390  81.7433  9.0412  0.5386  0.1947  0.1617
# 4     6.7749  74.4700  8.6296  0.5895  0.1938  0.1556
# 5     7.4633  89.2601  9.4478  0.5051  0.2127  0.1721
# 6     7.4320  87.8500  9.3728  0.5378  0.2201  0.1809
# 7     7.1627  82.4320  9.0792  0.5375  0.2040  0.1647
# 8     7.0270  82.9784  9.1092  0.5291  0.2134  0.1710
# 9     7.3239  85.0433  9.2219  0.5281  0.2145  0.1775
# Mean  7.1832  82.9557  9.1052  0.5407  0.2071  0.1688
# SD    0.1942   4.1013  0.2264  0.0210  0.0099  0.0082

# %% [markdown]
# ### 3.5 Plot Model
#
# * `plot_model` function takes a trained model object and returns a plot based on the test / hold-out set. The process may require the model to be re-trained in certain cases. See list of plots supported below. Model must be created using create_model() or tune_model().
#
#
#
# For more info please visit https://pycaret.org/regression/#plot-model

# %% [markdown]
# ### 3.5.1 Plotting learning curve

# %%
# plot_model(estimator = None, plot = ‘residuals’)
plot_model(estimator = tuned_br_age, plot = 'learning')

# %% [markdown]
# ### 3.5.2 plotting residuals

# %%
plot_model(estimator = tuned_br_age, plot = 'residuals')

# %% [markdown]
# ### 3.5.3 plotting feature importance

# %%
plot_model(estimator = tuned_br_age, plot = 'feature')

# %% [markdown]
# ### 3.6 Evaluate Model
#
# * `evaluate_model` function displays a user interface for all of the available plots for a given estimator. It internally uses the plot_model() function.
#
#
# For more info please visit https://pycaret.org/regression/#evaluate-model

# %%
evaluate_model(estimator=tuned_br_age)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2e5e9cbebb3b> in <module>
# ----> 1 evaluate_model(estimator=tuned_br_age)
#
# NameError: name 'tuned_br_age' is not defined

# %% [markdown]
# ### 3.7 Interpret Model
#
#
# * `interpret_model` function takes a trained model object and returns an interpretation plot based on the test / hold-out set. It only supports tree based algorithms. This function is implemented based on the SHAP (SHapley Additive exPlanations), which is a unified approach to explain the output of any machine learning model. SHAP connects game theory with local explanations.
#
# For more info please visit https://pycaret.org/regression/#interpret-model

# %% [markdown]
# interpret_model(
#     estimator=tuned_br_age,
#     plot = 'summary',
#     feature = None,
#     observation = None
# )

# %% [markdown]
# ### 3.8 Predict Model
#
# * `predict_model` function is used to predict new data using a trained estimator. It accepts an estimator created using one of the function in pycaret that returns a trained  model object or a list of trained model objects created using stack_models() or create_stacknet(). New unseen data can be passed to data param as pandas Dataframe.  If data is not passed, the test / hold-out set separated at the time of setup() is used to generate predictions.
#
# For more info please visit https://pycaret.org/regression/#predict-model

# %%
predictions =  predict_model(tuned_br_age, data=test_df)

# %%
predictions.head()
# Out:
#       Id  SCN(53)_vs_SCN(69)  SCN(98)_vs_SCN(69)  SCN(99)_vs_SCN(69)  \
# 0  10003            0.000687            0.000220            0.001483
# 1  10006            0.000647            0.000234            0.001281
# 2  10010           -0.000453           -0.000087            0.000669
# 3  10011            0.000335            0.000332            0.001042
# 4  10012            0.001039            0.000594            0.001191
#
#    SCN(45)_vs_SCN(69)  ADN(21)_vs_SCN(69)  ADN(56)_vs_SCN(69)  \
# 0            0.001157           -0.001353           -0.000874
# 1            0.000641           -0.000639           -0.000606
# 2            0.000638           -0.000342           -0.000519
# 3            0.000810           -0.000311           -0.000076
# 4            0.001549           -0.001016           -0.000164
#
#    SMN(3)_vs_SCN(69)  SMN(9)_vs_SCN(69)  SMN(2)_vs_SCN(69)  ...     IC_03  \
# 0          -0.000591          -0.000756          -0.000690  ...  0.030616
# 1          -0.000428          -0.000713          -0.000471  ...  0.019818
# 2          -0.000279           0.000070           0.000181  ...  0.020002
# 3          -0.000104           0.000104           0.000174  ...  0.022257
# 4           0.000077           0.000038           0.000344  ...  0.026314
#
#       IC_21     IC_28     IC_11     IC_20     IC_30     IC_22     IC_29  \
# 0  0.018184 -0.010469  0.029799  0.015435  0.005211 -0.028882  0.031427
# 1  0.003582 -0.010414  0.023518  0.005929  0.005046 -0.030771  0.028500
# 2  0.013935 -0.005653  0.013281  0.003379  0.004841 -0.009467  0.027287
# 3  0.008814 -0.003944  0.027572  0.008287  0.000210 -0.013350  0.033612
# 4  0.007632 -0.010203  0.022945  0.007642  0.003368 -0.024025  0.024723
#
#       IC_14    Label
# 0  0.018164  56.5443
# 1  0.022485  62.9394
# 2  0.014542  36.7010
# 3  0.019472  51.7802
# 4  0.024084  52.8963
#
# [5 rows x 1406 columns]

# %% [markdown]
# ## 4. Let's Proceed With Other Targets

# %% [markdown]
# ### 4.1. comparing models for `age`

# %% [markdown]
# For list of all available estimators and their abbreviations please visit https://pycaret.org/regression/

# %%
target = target_cols[0]
train_df = get_train_data(target)

setup_reg = setup(
    data = train_df,
    target = target,
    train_size=0.8,
    numeric_imputation = 'mean',
    silent = True
)

compare_models(
    blacklist = blacklist_models,
    fold = 10,
    sort = 'MAE',
    turbo = True
)
# Out:
# <style  type="text/css" >
#     #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710a th {
#           text-align: left;
#     }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow0_col0 {
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow0_col4 {
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow0_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow1_col0 {
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow1_col2 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow1_col4 {
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow2_col0 {
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow2_col4 {
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow3_col0 {
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow3_col4 {
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow4_col0 {
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow4_col4 {
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow5_col0 {
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow5_col4 {
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow6_col0 {
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow6_col4 {
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow7_col0 {
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow7_col4 {
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow8_col0 {
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow8_col2 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow8_col3 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow8_col4 {
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow8_col5 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow8_col6 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow9_col0 {
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow9_col1 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow9_col2 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow9_col3 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow9_col4 {
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow9_col5 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow9_col6 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow10_col0 {
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow10_col1 {
#             : ;
#             text-align:  left;
#         }    #T_05e1d4d8_91d6_11ea_b4b0_001a7dda710arow10_col2 {
#             : ;
#             text-align:  left;
#         }    #T_

# %% [markdown]
# ### 4.2. comparing models for `domain1_var1`

# %%
target = target_cols[1]
train_df = get_train_data(target)

setup_reg = setup(
    data = train_df,
    target = target,
    train_size=0.8,
    numeric_imputation = 'mean',
    silent = True
)

compare_models(
    blacklist = blacklist_models,
    fold = 10,
    sort = 'MAE',
    turbo = True
)
# Out:
# <style  type="text/css" >
#     #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710a th {
#           text-align: left;
#     }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow0_col0 {
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow0_col4 {
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow0_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow1_col0 {
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow1_col2 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow1_col4 {
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow2_col0 {
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow2_col4 {
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow3_col0 {
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow3_col4 {
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow4_col0 {
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow4_col4 {
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow5_col0 {
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow5_col4 {
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow6_col0 {
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow6_col4 {
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow7_col0 {
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow7_col4 {
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow8_col0 {
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow8_col2 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow8_col3 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow8_col4 {
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow8_col5 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow8_col6 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow9_col0 {
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow9_col1 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow9_col2 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow9_col3 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow9_col4 {
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow9_col5 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow9_col6 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow10_col0 {
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow10_col1 {
#             : ;
#             text-align:  left;
#         }    #T_db1a1c5c_91eb_11ea_a3b2_001a7dda710arow10_col2 {
#             : ;
#             text-align:  left;
#         }    #T_

# %% [markdown]
# ### 4.3. comparing models for `domain1_var2`

# %%
target = target_cols[2]
train_df = get_train_data(target)

setup_reg = setup(
    data = train_df,
    target = target,
    train_size=0.8,
    numeric_imputation = 'mean',
    silent = True
)

compare_models(
    blacklist = blacklist_models,
    fold = 10,
    sort = 'MAE',
    turbo = True
)
# Out:
# <style  type="text/css" >
#     #T_ccf7644c_9204_11ea_b00b_001a7dda710a th {
#           text-align: left;
#     }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow0_col0 {
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow0_col4 {
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow1_col0 {
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow1_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow1_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow1_col4 {
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow2_col0 {
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow2_col4 {
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow3_col0 {
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow3_col4 {
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow4_col0 {
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow4_col4 {
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow5_col0 {
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow5_col4 {
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow6_col0 {
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow6_col4 {
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow7_col0 {
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow7_col4 {
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow8_col0 {
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow8_col2 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow8_col3 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow8_col4 {
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow8_col5 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow8_col6 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow9_col0 {
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow9_col1 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow9_col2 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow9_col3 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow9_col4 {
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow9_col5 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow9_col6 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow10_col0 {
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow10_col1 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow10_col2 {
#             : ;
#             text-align:  left;
#         }    #T_ccf7644c_9204_11ea_b00b_001a7dda710arow10_col3

# %% [markdown]
# ### 4.4. comparing models for `domain2_var1`

# %%
target = target_cols[3]
train_df = get_train_data(target)

setup_reg = setup(
    data = train_df,
    target = target,
    train_size=0.8,
    numeric_imputation = 'mean',
    silent = True
)

compare_models(
    blacklist = blacklist_models,
    fold = 10,
    sort = 'MAE',
    turbo = True
)
# Out:
# <style  type="text/css" >
#     #T_4e4d038a_921e_11ea_8ac0_001a7dda710a th {
#           text-align: left;
#     }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow0_col0 {
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow0_col4 {
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow1_col0 {
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow1_col2 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow1_col4 {
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow1_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow1_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow2_col0 {
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow2_col4 {
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow3_col0 {
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow3_col4 {
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow4_col0 {
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow4_col4 {
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow5_col0 {
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow5_col4 {
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow6_col0 {
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow6_col4 {
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow7_col0 {
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow7_col4 {
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow8_col0 {
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow8_col2 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow8_col3 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow8_col4 {
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow8_col5 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow8_col6 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow9_col0 {
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow9_col1 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow9_col2 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow9_col3 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow9_col4 {
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow9_col5 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow9_col6 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow10_col0 {
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow10_col1 {
#             : ;
#             text-align:  left;
#         }    #T_4e4d038a_921e_11ea_8ac0_001a7dda710arow10_col2 {
#             : ;
#             text-align:  left;
#         }    #T_

# %% [markdown]
# ### 4.5. comparing models for `domain2_var2`

# %%
target = target_cols[4]
train_df = get_train_data(target)

setup_reg = setup(
    data = train_df,
    target = target,
    train_size=0.8,
    numeric_imputation = 'mean',
    silent = True
)

compare_models(
    blacklist = blacklist_models,
    fold = 10,
    sort = 'MAE',
    turbo = True
)
# Out:
# <style  type="text/css" >
#     #T_166929ae_9238_11ea_a9a4_001a7dda710a th {
#           text-align: left;
#     }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow0_col0 {
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow0_col4 {
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow1_col0 {
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow1_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow1_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow1_col4 {
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow2_col0 {
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow2_col4 {
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow2_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow3_col0 {
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow3_col4 {
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow4_col0 {
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow4_col4 {
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow5_col0 {
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow5_col4 {
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow6_col0 {
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow6_col4 {
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow7_col0 {
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow7_col4 {
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow8_col0 {
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow8_col2 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow8_col3 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow8_col4 {
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow8_col5 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow8_col6 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow9_col0 {
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow9_col1 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow9_col2 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow9_col3 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow9_col4 {
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow9_col5 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow9_col6 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow10_col0 {
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow10_col1 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4_001a7dda710arow10_col2 {
#             : ;
#             text-align:  left;
#         }    #T_166929ae_9238_11ea_a9a4

# %% [markdown]
# ### Observations:
#
# On close observation of above model comparisons, we have made following observations:
# * `age`: Bayesian Ridge	has the minimum MAE
# * `domain1_var1`: CatBoost Regressor has the minimum MAE
# * `domain1_var2`: Support Vector Machines has the minimum MAE
# * `domain2_var1`: CatBoost Regressor has the minimum MAE
# * `domain2_var2`: CatBoost Regressor has the minimum MAE
#
# > **Note: For demo purpose i have taken the model with lowest MAE in each target category, feel free to experiment with lowest 2 or 3 models and also try ensemble of various models in each category for better results.**

# %% [markdown]
# ## 5. Tuning Selected Models

# %%
# mapping targets to their corresponding models

models = []

target_models_dict = {
    'age': 'br',
    'domain1_var1':'catboost',
    'domain1_var2':'svm',
    'domain2_var1':'catboost',
    'domain2_var2':'catboost',
}

def tune_and_ensemble(target):
    train_df = get_train_data(target)    
    exp_reg = setup(
        data = train_df,
        target = target,
        train_size=0.8,
        numeric_imputation = 'mean',
        silent = True
    )
    
    model_name = target_models_dict[target]
    tuned_model = tune_model(model_name, fold=10)
    model = ensemble_model(tuned_model, fold=10)
    return model

# %% [markdown]
# ### 5.1 Tuning Bayesian Ridge Model for `age`

# %%
target = target_cols[0]
model = tune_and_ensemble(target)
models.append(model)
# Out:
#          MAE      MSE    RMSE      R2   RMSLE    MAPE
# 0     7.0125  80.2215  8.9566  0.5203  0.2005  0.1601
# 1     7.0769  81.5043  9.0280  0.5459  0.2118  0.1712
# 2     7.0418  79.8876  8.9380  0.5534  0.1972  0.1594
# 3     7.5294  92.8157  9.6341  0.5100  0.2080  0.1691
# 4     7.2757  85.6066  9.2524  0.5048  0.2066  0.1692
# 5     7.0730  79.6866  8.9267  0.5521  0.1959  0.1609
# 6     7.1198  80.1170  8.9508  0.5508  0.1978  0.1624
# 7     7.0079  79.3826  8.9097  0.5628  0.2011  0.1626
# 8     7.4592  88.6627  9.4161  0.5499  0.2182  0.1756
# 9     7.3599  87.6921  9.3644  0.5541  0.2106  0.1729
# Mean  7.1956  83.5577  9.1377  0.5404  0.2048  0.1663
# SD    0.1848   4.5402  0.2459  0.0195  0.0070  0.0056

# %% [markdown]
# ### 5.2 Tuning CatBoost Regressor Model for `domain1_var1`

# %%
target = target_cols[1]
model = tune_and_ensemble(target)
models.append(model)
# %tb
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_d51dcc28_9289_11ea_940b_001a7dda710arow4_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_d51dcc28_9289_11ea_940b_001a7dda710a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d51dcc28_9289_11ea_940b_001a7dda710alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow0_col1" class="data row0 col1" >4229</td>
#             </tr>
#             <tr>
#                         <th id="T_d51dcc28_9289_11ea_940b_001a7dda710alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow1_col0" class="data row1 col0" >Transform Target </td>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow1_col1" class="data row1 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d51dcc28_9289_11ea_940b_001a7dda710alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow2_col0" class="data row2 col0" >Transform Target Method</td>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_d51dcc28_9289_11ea_940b_001a7dda710alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow3_col1" class="data row3 col1" >(5877, 1406)</td>
#             </tr>
#             <tr>
#                         <th id="T_d51dcc28_9289_11ea_940b_001a7dda710alevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow4_col1" class="data row4 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_d51dcc28_9289_11ea_940b_001a7dda710alevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow5_col1" class="data row5 col1" >1405</td>
#             </tr>
#             <tr>
#                         <th id="T_d51dcc28_9289_11ea_940b_001a7dda710alevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow6_col1" class="data row6 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_d51dcc28_9289_11ea_940b_001a7dda710alevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d51dcc28_9289_11ea_940b_001a7dda710alevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d51dcc28_9289_11ea_940b_001a7dda710alevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_d51dcc28_9289_11ea_940b_001a7dda710alevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow10_col1" class="data row10 col1" >(5439, 1406)</td>
#             </tr>
#             <tr>
#                         <th id="T_d51dcc28_9289_11ea_940b_001a7dda710alevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow11_col1" class="data row11 col1" >(4351, 1405)</td>
#             </tr>
#             <tr>
#                         <th id="T_d51dcc28_9289_11ea_940b_001a7dda710alevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow12_col1" class="data row12 col1" >(1088, 1405)</td>
#             </tr>
#             <tr>
#                         <th id="T_d51dcc28_9289_11ea_940b_001a7dda710alevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_d51dcc28_9289_11ea_940b_001a7dda710alevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_d51dcc28_9289_11ea_940b_001a7dda710alevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d51dcc28_9289_11ea_940b_001a7dda710alevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_d51dcc28_9289_11ea_940b_001a7dda710alevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d51dcc28_9289_11ea_940b_001a7dda710alevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_d51dcc28_9289_11ea_940b_001a7dda710arow18_col0" class="data row18 col0" >Transformation Method </td>
# IntProgress(value=0, description='Processing: ', max=16)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                08:45:27
# Status     . . . . . . . . . . . . . . . . . .  Tuning Hyperparameters
# ETC        . . . . . . . . . . . . . . . . . .         Calculating ETC
# Empty DataFrame
# Columns: [MAE, MSE, RMSE, R2, RMSLE, MAPE]
# Index: []

# %%
target
# Out:
# 'domain1_var1'

# %% [markdown]
# ### 5.3 Tuning Support Vector Machines Model for `domain1_var2`

# %%
target = target_cols[2]
model = tune_and_ensemble(target)
models.append(model)
# Out:
#          MAE       MSE     RMSE      R2   RMSLE    MAPE
# 0     8.7711  120.8143  10.9916 -0.0229  0.2054  0.1727
# 1     9.0930  128.8076  11.3493  0.0002  0.2058  0.1720
# 2     9.2257  134.1860  11.5839 -0.0058  0.2180  0.1819
# 3     8.6597  118.4411  10.8831 -0.0026  0.1980  0.1643
# 4     8.7804  129.7071  11.3889 -0.0054  0.2151  0.1744
# 5     9.3270  147.2795  12.1359  0.0000  0.2365  0.1928
# 6     8.4079  114.2230  10.6875  0.0006  0.1956  0.1596
# 7     9.3220  143.5689  11.9820 -0.0073  0.2264  0.1866
# 8     8.9382  131.9741  11.4880 -0.0071  0.2188  0.1780
# 9     8.9407  137.7757  11.7378 -0.0066  0.2760  0.3121
# Mean  8.9466  130.6777  11.4228 -0.0057  0.2196  0.1894
# SD    0.2857   10.1409   0.4444  0.0065  0.0223  0.0419

# %% [markdown]
# ### 5.4 Tuning CatBoost Regressor Model for `domain2_var1`

# %%
target = target_cols[3]
model = tune_and_ensemble(target)
models.append(model)
# Out:
#          MAE       MSE     RMSE      R2   RMSLE    MAPE
# 0     8.8080  121.3293  11.0150  0.0065  0.2667  0.2289
# 1     8.6673  124.8119  11.1719  0.0212  0.2600  0.2156
# 2     8.7639  129.8824  11.3966  0.0305  0.3255  0.3085
# 3     8.7459  123.2161  11.1003  0.0200  0.2688  0.2284
# 4     8.7371  118.9989  10.9087  0.0053  0.2599  0.2266
# 5     9.0092  133.6227  11.5595  0.0081  0.3195  0.3046
# 6     8.7145  119.8810  10.9490  0.0180  0.2460  0.2085
# 7     9.1533  134.0522  11.5781  0.0081  0.3176  0.3033
# 8     8.6672  118.7869  10.8989  0.0285  0.2923  0.3167
# 9     8.3449  107.2954  10.3583  0.0290  0.2644  0.2887
# Mean  8.7611  123.1877  11.0936  0.0175  0.2821  0.2630
# SD    0.2028    7.6043   0.3449  0.0094  0.0277  0.0423

# %% [markdown]
# ### 5.5 Tuning CatBoost Regressor Model for `domain2_var2`

# %%
target = target_cols[4]
model = tune_and_ensemble(target)
models.append(model)
# Out:
#          MAE       MSE     RMSE      R2   RMSLE    MAPE
# 0     9.4937  145.8996  12.0789  0.0160  0.3001  0.3538
# 1     9.4762  145.3121  12.0545  0.0302  0.2634  0.2237
# 2     8.9731  131.1667  11.4528  0.0275  0.2595  0.2173
# 3     9.1996  137.0692  11.7077  0.0233  0.2575  0.2151
# 4     9.4238  143.6641  11.9860  0.0179  0.2586  0.2205
# 5     8.5562  121.9498  11.0431  0.0235  0.2398  0.1975
# 6     9.1275  136.1833  11.6698  0.0206  0.2442  0.2007
# 7     9.0098  133.3609  11.5482  0.0065  0.2512  0.2068
# 8     9.4251  141.5205  11.8962  0.0021  0.2622  0.2235
# 9     9.4000  147.5134  12.1455  0.0073  0.2768  0.2322
# Mean  9.2085  138.3640  11.7583  0.0175  0.2613  0.2291
# SD    0.2846    7.6126   0.3272  0.0090  0.0162  0.0428

# %% [markdown]
# ## 6. Finalize, save model and Inference

# %%
### create a pipeline or function to run for all targets

def finalize_model_pipeline(model, target):
    # this will train the model on holdout data
    finalize_model(model)
    save_model(model, f'{target}_{target_models_dict[target]}', verbose=True)
    # making predictions on test data
    predictions = predict_model(model, data=test_df)
    test_df[target] = predictions['Label'].values

# %%
for index, target in enumerate(target_cols):
    model = models[index]
    finalize_model_pipeline(model,target)

# %% [markdown]
# ## Create Submission

# %%
sub_df = pd.melt(test_df[["Id", "age", "domain1_var1", "domain1_var2", "domain2_var1", "domain2_var2"]], id_vars=["Id"], value_name="Predicted")
sub_df["Id"] = sub_df["Id"].astype("str") + "_" +  sub_df["variable"].astype("str")

sub_df = sub_df.drop("variable", axis=1).sort_values("Id")
assert sub_df.shape[0] == test_df.shape[0]*5

sub_df.to_csv("submission1.csv", index=False)

# %%
sub_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-92e73a68bae7> in <module>
# ----> 1 sub_df
#
# NameError: name 'sub_df' is not defined

# %% [markdown]
# # References
#
# * https://pycaret.org/regression/
# * https://towardsdatascience.com/machine-learning-in-power-bi-using-pycaret-34307f09394a

# %% [markdown]
# # END NOTES
#
# * This notebook is work in progress.  I will kepp updating this kernel with more and more info.
# * Feel free to use this kernel as the starting point. Happy kaggling:)
#
# **<span style="color:Red">Please upvote this kernel if you like it . It motivates me to produce more quality content :)**
